# %%
# import libraries
import yfinance as yf
import pandas as pd
import numpy as py

# %%
# download vvix dataset
vvix = yf.download('^VVIX', start='2007-01-01', end='2025-10-05')
vvix.head()
# Out:
# /tmp/ipython-input-451270322.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   vvix = yf.download('^VVIX', start='2007-01-01', end='2025-10-05')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open Volume
# Ticker          ^VVIX      ^VVIX      ^VVIX      ^VVIX  ^VVIX
# Date
# 2007-01-03  87.629997  87.629997  87.629997  87.629997      0
# 2007-01-04  88.190002  88.190002  88.190002  88.190002      0
# 2007-01-05  90.169998  90.169998  90.169998  90.169998      0
# 2007-01-08  92.040001  92.040001  92.040001  92.040001      0
# 2007-01-09  92.760002  92.760002  92.760002  92.760002      0

# %%
# save vvix dataset as csv
vvix.to_csv('vvix.csv')
